# %%
import pandas as pd
import seaborn as sns
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, classification_report

# %%
df = pd.read_csv("/content/drive/MyDrive/Ciências de dados rep/Categorization/creditFraud/creditcard.csv")

# %%
df_0 = df[df["Class"] == 0]
df_1 = df[df["Class"] == 1]

# %%
X = ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
     'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
     'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']
y = ['Class']
test_d0 = df_0.sample(n=int(len(df_0)/3),random_state=42)
test_d1 = df_1.sample(n=int(len(df_1)/3),random_state=42)
test_df = shuffle(pd.concat([test_d0,test_d1])).reset_index(drop=True)
test_df_X = test_df[X]
test_df_y = test_df[y]

train_d0 = df_0[~df_0.index.isin(test_d0.index)]
train_d1 = df_1[~df_1.index.isin(test_d1.index)]
train_df = shuffle(pd.concat([train_d0,train_d1])).reset_index(drop=True)
train_df_X = train_df[X]
train_df_y = train_df[y]

# %%
DTC = DecisionTreeClassifier(random_state=42)
KNN = KNeighborsClassifier()
LRC = LogisticRegression(random_state=42)
DTC.fit(train_df_X,train_df_y)
KNN.fit(train_df_X,train_df_y)
LRC.fit(train_df_X,train_df_y)
prev_dtc = DTC.predict(test_df_X)
prev_knn = KNN.predict(test_df_X)
prev_lrc = LRC.predict(test_df_X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
print("DecisionTreeClassifier accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_lrc)))
print("=="*50)
print("DecisionTreeClassifier confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_lrc)))
print("=="*50)
print("DecisionTreeClassifier classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_lrc)))
# Out:
# DecisionTreeClassifier accuracy: 0.9992310528256175
# KNeighborsClassifier accuracy: 0.9983146363301206
# LogisticRegression accuracy: 0.9988939800916417
# ...
# DecisionTreeClassifier confusion_matrix:
# [[94729    42]
#  [   31   133]]
# KNeighborsClassifier confusion_matrix:
# [[94771     0]
#  [  160     4]]
# LogisticRegression confusion_matrix:
# [[94726    45]
#  [   60   104]]
# ...
# DecisionTreeClassifier classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     94771
#            1       0.76      0.81      0.78       164
#
#     accuracy                           1.00     94935
#    macro avg       0.88      0.91      0.89     94935
# weighted avg       1.00      1.00      1.00     94935
#
# KNeighborsClassifier classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     94771
#            1       1.00      0.02      0.05       164
#
# ...

# %%
X_n = ['Time', 'V1', 'V3', 'V4', 'V7', 'V10',
     'V11', 'V12', 'V14', 'V16', 'V17', 'V18', 'Amount']

test_d0 = df_0.sample(n=int(len(df_0)/3),random_state=42)
test_d1 = df_1.sample(n=int(len(df_1)/3),random_state=42)
test_df = shuffle(pd.concat([test_d0,test_d1])).reset_index(drop=True)
test_df_Xn = test_df[X_n]
test_df_y = test_df[y]

train_d0 = df_0[~df_0.index.isin(test_d0.index)]
train_d1 = df_1[~df_1.index.isin(test_d1.index)]
train_df = shuffle(pd.concat([train_d0,train_d1])).reset_index(drop=True)
train_df_Xn = train_df[X_n]
train_df_y = train_df[y]

# %%
DTC = DecisionTreeClassifier(random_state=42)
KNN = KNeighborsClassifier()
LRC = LogisticRegression(random_state=42)
DTC.fit(train_df_Xn,train_df_y)
KNN.fit(train_df_Xn,train_df_y)
LRC.fit(train_df_Xn,train_df_y)
prev_dtc = DTC.predict(test_df_Xn)
prev_knn = KNN.predict(test_df_Xn)
DTC = DecisionTreeClassifier(random_state=42)
KNN = KNeighborsClassifier()
LRC = LogisticRegression(random_state=42)
DTC.fit(train_df_Xn,train_df_y)
KNN.fit(train_df_Xn,train_df_y)
LRC.fit(train_df_Xn,train_df_y)
prev_dtc = DTC.predict(test_df_Xn)
prev_knn = KNN.predict(test_df_Xn)
prev_lrc = LRC.predict(test_df_Xn)
prev_lrc = LRC.predict(test_df_Xn)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
print("DecisionTreeClassifier accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_lrc)))

print("=="*50)

print("DecisionTreeClassifier confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_lrc)))

print("=="*50)

print("DecisionTreeClassifier classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_lrc)))
# Out:
# DecisionTreeClassifier accuracy: 0.9993047874861748
# KNeighborsClassifier accuracy: 0.9983041028071838
# LogisticRegression accuracy: 0.9987781113393375
# ...
# DecisionTreeClassifier confusion_matrix:
# [[94742    29]
#  [   37   127]]
# KNeighborsClassifier confusion_matrix:
# [[94770     1]
#  [  160     4]]
# LogisticRegression confusion_matrix:
# [[94722    49]
#  [   67    97]]
# ...
# DecisionTreeClassifier classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     94771
#            1       0.81      0.77      0.79       164
#
#     accuracy                           1.00     94935
#    macro avg       0.91      0.89      0.90     94935
# weighted avg       1.00      1.00      1.00     94935
#
# KNeighborsClassifier classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     94771
#            1       0.80      0.02      0.05       164
#
# ...

# %%
X_n_ = ['Time', 'V3', 'V4', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'Amount']

# %%
test_d0 = df_0.sample(n=int(len(df_0)/3),random_state=42)
test_d1 = df_1.sample(n=int(len(df_1)/3),random_state=42)
test_df = shuffle(pd.concat([test_d0,test_d1])).reset_index(drop=True)
test_df_Xn_ = test_df[X_n_]
test_df_y = test_df[y]

train_d0 = df_0[~df_0.index.isin(test_d0.index)]
train_d1 = df_1[~df_1.index.isin(test_d1.index)]
train_df = shuffle(pd.concat([train_d0,train_d1])).reset_index(drop=True)
train_df_Xn_ = train_df[X_n_]
train_df_y = train_df[y]

# %%
DTC = DecisionTreeClassifier(random_state=42)
KNN = KNeighborsClassifier()
LRC = LogisticRegression(random_state=42)
DTC.fit(train_df_Xn_,train_df_y)
KNN.fit(train_df_Xn_,train_df_y)
LRC.fit(train_df_Xn_,train_df_y)
prev_dtc = DTC.predict(test_df_Xn_)
prev_knn = KNN.predict(test_df_Xn_)
prev_lrc = LRC.predict(test_df_Xn_)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print("DecisionTreeClassifier accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression accuracy: {}".format(accuracy_score(test_df_y["Class"].values,prev_lrc)))

print("=="*50)

print("DecisionTreeClassifier confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression confusion_matrix: \n{}".format(confusion_matrix(test_df_y["Class"].values,prev_lrc)))

print("=="*50)

print("DecisionTreeClassifier classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_dtc)))
print("KNeighborsClassifier classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_knn)))
print("LogisticRegression classification_report: \n{}".format(classification_report(test_df_y["Class"].values,prev_lrc)))
# Out:
# DecisionTreeClassifier accuracy: 0.99912571759625
# KNeighborsClassifier accuracy: 0.9982935692842471
# LogisticRegression accuracy: 0.99912571759625
# ...
# DecisionTreeClassifier confusion_matrix:
# [[94727    44]
#  [   39   125]]
# KNeighborsClassifier confusion_matrix:
# [[94770     1]
#  [  161     3]]
# LogisticRegression confusion_matrix:
# [[94740    31]
#  [   52   112]]
# ...
# DecisionTreeClassifier classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     94771
#            1       0.74      0.76      0.75       164
#
#     accuracy                           1.00     94935
#    macro avg       0.87      0.88      0.88     94935
# weighted avg       1.00      1.00      1.00     94935
#
# KNeighborsClassifier classification_report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     94771
#            1       0.75      0.02      0.04       164
#
# ...
