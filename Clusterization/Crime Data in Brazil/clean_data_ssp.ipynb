# %%
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder

# %%
def cleanStr(i):
    if len(i.split(",")) > 1:
        i = int(i.split(",")[0])
    if "§" in str(i):
        i=i.split("§")[0]
    if "-" in str(i):
        i=i.split("-")[0]
    if "." in str(i):
        i=i.split(".")[0]
    return int(i)

def returnHour(i):
    try:
        i = i.replace(":","")[:2]
    except:
        i = 99
    return i

def returnMinute(i):
    try:
        i = i.replace(":","")[2:]
    except:
        i = 99
    return i

# %%
df = pd.read_csv("BO_2007_1.csv")
# Out:
# d:\Ciencias de Dados\Projetos\Concluidos\Ciencias-de-dados\venv\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,21,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df["RUBRICA_x"] = df["RUBRICA"].apply(lambda x: x.split("(")[1][4:].replace(")",""))
df["RUBRICA_final"] = df["RUBRICA_x"].apply(lambda x: cleanStr(x))
df["H_OCORRENCIA_BO"] = df["HORA_OCORRENCIA_BO"].apply(lambda x: returnHour(x))
df["M_OCORRENCIA_BO"] = df["HORA_OCORRENCIA_BO"].apply(lambda x: returnMinute(x))
df["DT_OCORRENCIA_BO"] = pd.to_datetime(df["DATA_OCORRENCIA_BO"])

descricao_le = LabelEncoder()
df["DESCR_TIPO_PESSOA_le"] = descricao_le.fit_transform(df["DESCR_TIPO_PESSOA"])
logradouro_le = LabelEncoder()
df["LOGRADOURO_le"] = logradouro_le.fit_transform(df["LOGRADOURO"])
city_le = LabelEncoder()
df["CIDADE_le"] = city_le.fit_transform(df["CIDADE"])
sexo_le = LabelEncoder()
df["SEXO_PESSOA_le"] = sexo_le.fit_transform(df["SEXO_PESSOA"])
cor_le = LabelEncoder()
df["COR_le"] = cor_le.fit_transform(df["COR"])

secc_le = LabelEncoder()
df["NOME_SECCIONAL_le"] = secc_le.fit_transform(df["NOME_SECCIONAL"])

# %%
df_clean = df[['NUM_BO', 'ANO_BO', 'NOME_SECCIONAL_le', 'ID_DELEGACIA', 'DT_OCORRENCIA_BO', 
    'H_OCORRENCIA_BO',"M_OCORRENCIA_BO", 'RUBRICA_final', 'CIDADE_le', 'LOGRADOURO_le',
    'DESCR_TIPO_PESSOA_le', 'SEXO_PESSOA_le', 'COR_le']]

# %%
df[df["DESCR_TIPO_PESSOA"] == "Vítima              "]
# Out:
#         NUM_BO  ANO_BO  ID_DELEGACIA  \
# 0            1    2007         10101
# 7            1    2007         10248
# 8            1    2007         10248
# 11           1    2007         10366
# 12           1    2007         10372
# ...        ...     ...           ...
# 725938  900642    2007         30312
# 725939  900648    2007         30312
# 725940  900650    2007         30312
# 725941  900652    2007         30312
# 725942  900660    2007         30312
#
#                                NOME_DEPARTAMENTO  \
# 0       DECAP
# 7       DECAP
# 8       DECAP
# 11      DECAP
# 12      DECAP
# ...                                          ...
# 725938  DEMACRO
# 725939  DEMACRO
# 725940  DEMACRO
# 725941  DEMACRO
# 725942  DEMACRO
#
#                                   NOME_SECCIONAL  \
# 0       DEL.SEC.1º CENTRO
# 7       DEL.SEC.6º SANTO AMARO
# 8       DEL.SEC.6º SANTO AMARO
# 11      DEL.SEC.6º SANTO AMARO
# 12      DEL.SEC.6º SANTO AMARO
# ...                                          ...
# 725938  DEL.SEC.MOGI DAS CRUZES
# 725939  DEL.SEC.MOGI DAS CRUZES
# 725940  DEL.SEC.MOGI DAS CRUZES
# 725941  DEL.SEC.MOGI DAS CRUZES
# 725942  DEL.SEC.MOGI DAS CRUZES
#
#                              DELEGACIA  \
# 0       01º D.P. SE
# 7       48º D.P.  CIDADE DUTRA
# 8       48º D.P.  CIDADE DUTRA
# 11      92º D.P. P. STO ANTONIO
# 12      99º D.P.  CAMPO GRANDE
# ...                                ...
# 725938  DEL.DEF.MUL. MOGI DAS CRUZES
# 725939  DEL.DEF.MUL. MOGI DAS CRUZES
# 725940  DEL.DEF.MUL. MOGI DAS CRUZES
# 725941  DEL.DEF.MUL. MOGI DAS CRUZES
# 725942  DEL.DEF.MUL. MOGI DAS CRUZES
#
#                           NOME_DEPARTAMENTO_CIRC  \
# 0       DECAP
# 7       DECAP
# 8       DECAP
# 11      DECAP
# 12      DECAP
# ...                                          ...
# 725938  DEMACRO
# 725939  DEMACRO
# 725940  DEMACRO
# 725941  DEMACRO
# 725942  DEMACRO
#
#                              NOME_SECCIONAL_CIRC  \
# 0       DEL.SEC.1º CENTRO
# 7       DEL.SEC.6º SANTO AMARO
# 8       DEL.SEC.6º SANTO AMARO
# 11      DEL.SEC.6º SANTO AMARO
# 12      DEL.SEC.6º SANTO AMARO
# ...                                          ...
# 725938  DEL.SEC.MOGI DAS CRUZES
# 725939  DEL.SEC.MOGI DAS CRUZES
# 725940  DEL.SEC.MOGI DAS CRUZES
# 725941  DEL.SEC.MOGI DAS CRUZES
# 725942  DEL.SEC.MOGI DAS CRUZES
#
#                    NOME_DELEGACIA_CIRC   ANO  ...  RUBRICA_final  \
# 0       01º D.P. SE                     2007  ...            155
# 7       48º D.P.  CIDADE DUTRA          2007  ...            302
# 8       48º D.P.  CIDADE DUTRA          2007  ...            302
# 11      92º D.P. P. STO ANTONIO         2007  ...            157
# 12      99º D.P.  CAMPO GRANDE          2007  ...            303
# ...                                ...   ...  ...            ...
# 725938  01º D.P. MOGI DAS CRUZES        2007  ...            129
# 725939  04º D.P. MOGI DAS CRUZES        2007  ...            129
# 725940  03º D.P. MOGI DAS CRUZES        2007  ...            129
# 725941  02º D.P. MOGI DAS CRUZES        2007  ...            129
# 725942  01º D.P. MOGI DAS CRUZES        2007  ...            129
#
#        H_OCORRENCIA_BO M_OCORRENCIA_BO DT_OCORRENCIA_BO DESCR_TIPO_PESSOA_le  \
# 0                   02              30       2007-01-01                   15
# 7                   05              23       2007-01-01                   15
# 8                   05              23       2007-01-01                   15
# 11                  99              99       2007-01-01                   15
# 12                  07              00       2007-01-01                   15
# ...                ...             ...              ...                  ...
# 725938              16              30       2007-12-03                   15
# 725939              23              30       2007-04-19                   15
# 725940              17              20       2007-06-14                   15
# 725941              17              00       2007-06-14                   15
# 725942              16              30       2007-06-16                   15
#
#        LOGRADOURO_le CIDADE_le SEXO_PESSOA_le COR_le NOME_SECCIONAL_le
# 0               2150        82              3      1                 2
# 7               3048        82              3      3                 8
# 8               3048        82              3      3                 8
# 11             40583        82              1      4                 8
# 12              3796        82              1      3                 8
# ...              ...       ...            ...    ...               ...
# 725938          2791        57              1      4                17
# 725939         38977        57              1      1                17
# 725940         43597        57              1      1                17
# 725941         25088        57              1      1                17
# 725942         24041        57              1      1                17
#
# [297341 rows x 41 columns]
