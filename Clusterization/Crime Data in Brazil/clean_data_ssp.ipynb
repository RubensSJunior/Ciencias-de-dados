# %%
import pandas as pd
import os

# %%
df = pd.read_csv("/content/drive/MyDrive/Ciências de dados rep/Clusterization/Crime Data in Brazil/BO_2007_1.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (17,18,21,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[['NUM_BO', 'ANO_BO', 'ID_DELEGACIA', 'DATA_OCORRENCIA_BO', 
    'HORA_OCORRENCIA_BO', 'RUBRICA', 'CIDADE', 'LOGRADOURO', 'NUMERO_LOGRADOURO',
    'DESCR_TIPO_PESSOA', 'CONT_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA', 'COR']]

# %%
df[df["HORA_OCORRENCIA_BO"].isna()]
# Out:
#         NUM_BO  ANO_BO  ...  IDADE_PESSOA                   COR
# 11           1    2007  ...            35  Preta
# 36           1    2008  ...            23                   NaN
# 37           1    2008  ...            33  Branca
# 39           1    2007  ...            32  Preta
# 65           1    2007  ...            22  Branca
# ...        ...     ...  ...           ...                   ...
# 725934  900591    2007  ...            22  Branca
# 725935  900600    2007  ...            31  Preta
# 725944  900666    2007  ...            33  Preta
# 725954  901031    2007  ...            38  Branca
# 725955  901042    2007  ...            51  Parda
#
# [90772 rows x 14 columns]
